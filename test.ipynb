# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/yintianshu/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['pylab', 'resize', 'imshow', 'imread', 'plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from skimage import data
from skimage.transform import resize

# %%
image = data.camera()

# %%
image.shape
# Out:
# (512, 512)

# %%
from skimage.io import imread,imshow

# %%
imshow(image)

# %%
image = data.camera()
imshow(image)

# %%
image1 = resize()
imshow(image1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6cd26c8e47fd> in <module>()
# ----> 1 image1 = resize(image,(256,256),mode='constant')
#       2 imshow(image1)
#
# TypeError: resize() got an unexpected keyword argument 'mode'
